# %% [markdown]
# # Decision Tree for Classification

# %%
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import datasets
from sklearn import tree
import matplotlib.pyplot as plt

# %%
iris_X, iris_y = datasets.load_iris(return_X_y = True)
X_train, X_test, y_train, y_test = train_test_split(iris_X, iris_y, test_size= 0.2, random_state=42)
clf = DecisionTreeClassifier(criterion = "gini", max_depth = 4 , min_samples_split= 20)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# 1.0

# %%
fig, ax = plt.subplots(figsize = (11,11))
tree.plot_tree(clf,ax = ax)
# Out:
# [Text(0.3333333333333333, 0.9, 'x[2] <= 2.45\ngini = 0.667\nsamples = 120\nvalue = [40, 41, 39]'),
#  Text(0.2222222222222222, 0.7, 'gini = 0.0\nsamples = 40\nvalue = [40, 0, 0]'),
#  Text(0.2777777777777778, 0.8, 'True  '),
#  Text(0.4444444444444444, 0.7, 'x[2] <= 4.75\ngini = 0.5\nsamples = 80\nvalue = [0, 41, 39]'),
#  Text(0.38888888888888884, 0.8, '  False'),
#  Text(0.2222222222222222, 0.5, 'x[3] <= 1.65\ngini = 0.053\nsamples = 37\nvalue = [0, 36, 1]'),
#  Text(0.1111111111111111, 0.3, 'gini = 0.0\nsamples = 36\nvalue = [0, 36, 0]'),
#  Text(0.3333333333333333, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.6666666666666666, 0.5, 'x[3] <= 1.75\ngini = 0.206\nsamples = 43\nvalue = [0, 5, 38]'),
#  Text(0.5555555555555556, 0.3, 'gini = 0.5\nsamples = 8\nvalue = [0, 4, 4]'),
#  Text(0.7777777777777778, 0.3, 'x[2] <= 4.85\ngini = 0.056\nsamples = 35\nvalue = [0, 1, 34]'),
#  Text(0.6666666666666666, 0.1, 'gini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
# ...

# %% [markdown]
# # Decision Tree for Regression

# %%
from sklearn import tree
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt

# %%
machine_cpu = datasets.fetch_openml(name ="machine_cpu")
machine_data = machine_cpu.data
machine_labels = machine_cpu.target
X_train, X_test, y_train, y_test = train_test_split(machine_data, machine_labels, test_size= 0.2, random_state=42)
reg = DecisionTreeRegressor(max_depth = 4 , min_samples_split= 10)
reg.fit(X_train, y_train)
y_pred = reg.predict(X_test)
print(metrics.mean_squared_error(y_test,y_pred))
# Out:
# 12443.176514577432
# c:\Users\PC\anaconda3\envs\buinhatlinh94_env\lib\site-packages\sklearn\datasets\_openml.py:320: UserWarning: Multiple active versions of the dataset matching the name machine_cpu exist. Versions may be fundamentally different, returning version 1. Available versions:
# - version 1, status: active
#   url: https://www.openml.org/search?type=data&id=230
# - version 2, status: active
#   url: https://www.openml.org/search?type=data&id=733
#
#   warn(warning_msg)

# %%
fig, ax = plt.subplots(figsize = (11,4))
tree.plot_tree(reg,ax = ax)
# Out:
# [Text(0.640625, 0.9, 'x[2] <= 28000.0\nsquared_error = 19224.451\nsamples = 167\nvalue = 99.449'),
#  Text(0.40625, 0.7, 'x[3] <= 27.0\nsquared_error = 3396.98\nsamples = 147\nvalue = 62.571'),
#  Text(0.5234375, 0.8, 'True  '),
#  Text(0.25, 0.5, 'x[2] <= 10000.0\nsquared_error = 710.672\nsamples = 113\nvalue = 39.903'),
#  Text(0.125, 0.3, 'x[2] <= 6100.0\nsquared_error = 324.499\nsamples = 91\nvalue = 32.308'),
#  Text(0.0625, 0.1, 'squared_error = 151.55\nsamples = 63\nvalue = 26.683'),
#  Text(0.1875, 0.1, 'squared_error = 482.249\nsamples = 28\nvalue = 44.964'),
#  Text(0.375, 0.3, 'x[1] <= 6000.0\nsquared_error = 1082.49\nsamples = 22\nvalue = 71.318'),
#  Text(0.3125, 0.1, 'squared_error = 489.324\nsamples = 21\nvalue = 65.905'),
#  Text(0.4375, 0.1, 'squared_error = 0.0\nsamples = 1\nvalue = 185.0'),
#  Text(0.5625, 0.5, 'x[2] <= 3810.0\nsquared_error = 4940.963\nsamples = 34\nvalue = 137.912'),
#  Text(0.5, 0.3, 'squared_error = 0.0\nsamples = 1\nvalue = 368.0'),
# ...
